# %%
# imports
import pandas as pd
from datetime import datetime
import finnhub
import numpy as np
import matplotlib.pyplot as plot
from sklearn.preprocessing import MinMaxScaler

# %%
client = finnhub.Client(api_key='bua9lb748v6q418gd0i0')

def get_candlestick_data(ticker, timeframe, start, end):
    # I think I need to add some await functionality to the finnhub API call
    data = client.stock_candles(ticker, timeframe, start, end)
    del data['s']
    df = pd.DataFrame.from_dict(data)
    df['t'] = df['t'].apply(lambda x: datetime.fromtimestamp(x))
    df = df.rename(columns={'c': 'Close', 'h': 'High', 'l': 'Low', 'o': 'Open', 't': 'Date', 'v': 'Volume'})
    df.set_index('Date', inplace=True)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    return df

# %%
amazon_data = get_candlestick_data('AMZN', 'D', 1281764208, 1603859231)
print(amazon_data)
# Out:
#                             Open         High          Low        Close  \
# Date
# 2010-08-15 17:00:00   123.610001   127.370003   123.040001   126.070000
# 2010-08-16 17:00:00   127.339996   129.979996   126.790001   128.860001
# 2010-08-17 17:00:00   129.250000   130.809998   128.259995   129.649994
# 2010-08-18 17:00:00   129.220001   130.020004   126.820000   127.570000
# 2010-08-19 17:00:00   127.199997   128.039993   126.019997   127.760002
# ...                          ...          ...          ...          ...
# 2020-10-21 17:00:00  3189.870117  3198.000000  3122.250000  3176.399902
# 2020-10-22 17:00:00  3191.000000  3205.330078  3140.000000  3204.399902
# 2020-10-25 17:00:00  3196.020020  3281.419922  3153.540039  3207.040039
# 2020-10-26 17:00:00  3223.000000  3291.179932  3212.260010  3286.330078
# 2020-10-27 17:00:00  3248.719971  3264.020020  3162.780029  3162.780029
#
#                       Volume
# Date
# 2010-08-15 17:00:00  4027614
# 2010-08-16 17:00:00  5045092
# 2010-08-17 17:00:00  7902371
# 2010-08-18 17:00:00  5582487
# 2010-08-19 17:00:00  4172548
# ...                      ...
# 2020-10-21 17:00:00  4212005
# 2020-10-22 17:00:00  3466687
# 2020-10-25 17:00:00  5901151
# 2020-10-26 17:00:00  4291047
# 2020-10-27 17:00:00  5588330
#
# [2571 rows x 5 columns]

# %%
open_data = amazon_data.iloc[:, 0:5].to_numpy()
scaler = MinMaxScaler(feature_range = (0, 1))
open_data = scaler.fit_transform(open_data)

# to undo:
# open_data = scaler.inverse_transform(open_data)
# open_data = pd.DataFrame(data=open_data, index=amazon_data.index)
# print(open_data)

# %%
data_train = open_data[:2056]
data_test = open_data[2030:]

# %%
# Create x_train and y_train tensors
x_train = []
y_train = []

# ! what about stocks that don't have at least a year's worth of trading data
# 2056 - 7 = 2049
for i in range(253, 2049):
    x_train.append(data_train[i-253:i])
    y_train.append(data_train[i:i+7])

x_train = np.asarray(x_train)
y_train = np.asarray(y_train)

# x_train.shape = (1796, 253, 5)
# y_train.shape = (1796, 7, 5)

# %%
# Create x_test and y_test tensors
x_test = []
y_test = []

# data_test.shape = (540, 5)
for i in range(253, 533):
    x_test.append(data_test[i-253:i])
    y_test.append(data_test[i:i+7])

x_test = np.asarray(x_test)
y_test = np.asarray(y_test)

# x_test.shape = (280, 253, 5)
# y_test.shape = (280, 7, 5)

# %%
y_train.shape[1]
# Out:
# 7

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras.callbacks import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

model = Sequential([
  layers.LSTM(units=300, return_sequences=False, input_shape=(253, 5)),
  layers.RepeatVector(7),
  layers.Dropout(0.2),
  layers.LSTM(units=300, return_sequences=True),
#   layers.RepeatVector(7),
  layers.Dropout(0.2),
  layers.LSTM(units=300, return_sequences=True),
#   layers.RepeatVector(7),
  layers.Dropout(0.2),
  layers.LSTM(units=300, return_sequences=True),
#   layers.RepeatVector(7),
  layers.Dropout(0.2),
#   layers.LSTM(units=200, return_sequences=False),
#   layers.RepeatVector(7),
#   layers.Dropout(0.2),
#   layers.LSTM(units=250, return_sequences=True),
#   layers.Dropout(0.2),
#   layers.LSTM(units=200, return_sequences=True),
#   layers.Dropout(0.1),
#   layers.LSTM(units=200, return_sequences=True),
#   layers.Dropout(0.1),
#   layers.LSTM(units=200, return_sequences=True),
#   layers.Dropout(0.1),
  layers.TimeDistributed(Dense(5))
])

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

mcp_save = ModelCheckpoint('mdl_wts.hdf5', save_best_only=True, monitor='val_loss', mode='min')
earlyStopping = EarlyStopping(monitor='val_loss', patience=200, verbose=0, mode='min')

model.fit(x_train,y_train, epochs=1000, batch_size=64, validation_split=0.15, callbacks=[mcp_save,earlyStopping])
# Out:
# Epoch 1/1000
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0075 - val_loss: 0.0346
# Epoch 2/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0033 - val_loss: 0.0159
# Epoch 3/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0025 - val_loss: 0.0087
# Epoch 4/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0023 - val_loss: 0.0064
# Epoch 5/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0021 - val_loss: 0.0066
# Epoch 6/1000
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0021 - val_loss: 0.0057
# Epoch 7/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 8/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0020 - val_loss: 0.0039
# Epoch 9/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 10/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 11/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 12/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 13/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 14/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 15/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 16/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 17/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 18/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 19/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 20/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 21/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 22/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 23/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 24/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 25/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0019 - val_loss: 0.0036
# Epoch 26/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 27/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 28/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 29/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 30/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 31/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0036
# Epoch 32/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 33/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 34/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 35/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 36/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 37/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 38/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 39/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 40/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 41/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 42/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 43/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 44/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 45/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0034
# Epoch 46/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 47/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 48/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 49/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 50/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 51/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 52/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 53/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 54/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 55/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 56/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 57/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 58/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 59/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 60/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 61/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 62/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 63/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 64/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 65/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 66/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 67/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 68/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 69/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 70/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 71/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 72/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 73/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 74/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 75/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 76/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 77/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 78/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 79/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 80/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 81/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 82/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 83/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 84/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 85/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 86/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 87/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 88/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 89/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 90/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 91/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0036
# Epoch 92/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 93/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 94/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 95/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 96/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 97/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 98/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 99/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 100/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 101/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 102/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 103/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 104/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 105/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0018 - val_loss: 0.0043
# Epoch 106/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 107/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 108/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 109/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 110/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 111/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 112/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 113/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 114/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 115/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 116/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 117/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 118/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 119/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 120/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 121/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 122/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 123/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 124/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 125/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 126/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 127/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 128/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 129/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 130/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 131/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 132/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 133/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 134/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 135/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 136/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 137/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 138/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 139/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 140/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 141/1000
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 142/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 143/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 144/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 145/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 146/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 147/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 148/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 149/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 150/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 151/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 152/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 153/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 154/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 155/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0045
# Epoch 156/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 157/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 158/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 159/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 160/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 161/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 162/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 163/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0017 - val_loss: 0.0044
# Epoch 164/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 165/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 166/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 167/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 168/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0055 - val_loss: 0.1059
# Epoch 169/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0066 - val_loss: 0.0852
# Epoch 170/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0061 - val_loss: 0.0827
# Epoch 171/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0061 - val_loss: 0.0835
# Epoch 172/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0060 - val_loss: 0.0735
# Epoch 173/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0042 - val_loss: 0.0281
# Epoch 174/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0028 - val_loss: 0.0247
# Epoch 175/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0024 - val_loss: 0.0229
# Epoch 176/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0023 - val_loss: 0.0203
# Epoch 177/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0022 - val_loss: 0.0209
# Epoch 178/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0022 - val_loss: 0.0195
# Epoch 179/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0022 - val_loss: 0.0187
# Epoch 180/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0022 - val_loss: 0.0194
# Epoch 181/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0021 - val_loss: 0.0199
# Epoch 210/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0020 - val_loss: 0.0224
# Epoch 211/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0020 - val_loss: 0.0238
# Epoch 212/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0019 - val_loss: 0.0207
# Epoch 213/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0221
# Epoch 214/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0020 - val_loss: 0.0223
# Epoch 215/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 0.0219
# Epoch 216/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0020 - val_loss: 0.0273
# Epoch 217/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0229
# Epoch 218/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0234
# Epoch 219/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0249
# Epoch 220/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0262
# Epoch 221/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0246
# Epoch 222/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 0.0256
# Epoch 223/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0256
# Epoch 224/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0241
# Epoch 225/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 0.0256
# Epoch 226/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0019 - val_loss: 0.0253
# Epoch 227/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0240
# Epoch 228/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0210
# Epoch 229/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0204
# Epoch 230/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 0.0248
# Epoch 231/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0228
# Epoch 232/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 0.0241
# Epoch 233/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0242
# Epoch 234/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0236
# Epoch 235/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 0.0228
# Epoch 236/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 0.0271
# Epoch 237/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0019 - val_loss: 0.0231
# Epoch 238/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0250
# Epoch 239/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0258
# Epoch 240/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0227
# Epoch 241/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0253
# Epoch 242/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0243
# Epoch 243/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0019 - val_loss: 0.0238
# Epoch 244/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0018 - val_loss: 0.0239
# Epoch 245/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0163
# Epoch 246/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0019 - val_loss: 0.0175
# Epoch 247/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0018 - val_loss: 0.0187
# Epoch 248/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0018 - val_loss: 0.0209
# Epoch 249/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0019 - val_loss: 0.0229
# Epoch 250/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0019 - val_loss: 0.0292
# Epoch 251/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.0020 - val_loss: 0.0232
# Epoch 252/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0230
# Epoch 253/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.0019 - val_loss: 0.0282
# Epoch 254/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0023 - val_loss: 0.0196
# Epoch 255/1000
# 10/24 [===========>..................] - ETA: 0s - loss: 0.0021

# %%
import matplotlib.pyplot as plt
import mplfinance as mpf
from tensorflow.keras.models import load_model
prediction_model = load_model('minimize_size_weights.hdf5')

predictions = prediction_model.predict(x_test) # print(predictions.shape) = (280, 7, 5)
predictions = scaler.inverse_transform(predictions.reshape(-1, predictions.shape[-1])).reshape(predictions.shape)


print(predictions.shape)

print(predictions[0][6])

combined = []

for i in predictions:
    combined.append(i[6])

combined = combined[:len(combined)-7]

combined = pd.DataFrame(combined, index=amazon_data.index[len(amazon_data.index)-273:])
combined = combined.rename(columns={0: 'Open', 1: 'High', 2: 'Low', 3: 'Close', 4: 'Volume'})

print(amazon_data.tail(30))
mpf.plot(amazon_data.tail(30), type='candle', volume=True)

print(combined.tail(30))
mpf.plot(combined.tail(30), type='candle', volume=True)

overlay = mpf.make_addplot(combined, type='candle', secondary_y=False)
mpf.plot(amazon_data.tail(273), addplot=overlay, type='candle', style='yahoo')

# plots = []

# for i in range(2,3):
#     dates = [amazon_data.index[j] for j in range(i,i+7)]
#     forecast = pd.DataFrame(data=predictions[i], index=dates)
#     forecast = forecast.rename(columns={0: 'Open', 1: 'High', 2: 'Low', 3: 'Close', 4: 'Volume'})
#     plots.append(mpf.make_addplot(forecast, type='candle', secondary_y=False))


# print(plots[0])
# dates = [amazon_data.index[i] for i in range(7)]
# for i in range(7):
#     dates.append(amazon_data.index[i])
    
# print(dates)

# print(predictions[0])
# print(predictions.shape)

# test = pd.DataFrame(data=predictions[0], index=dates)
# test = test.rename(columns={0: 'Open', 1: 'High', 2: 'Low', 3: 'Close', 4: 'Volume'})

# apds = [mpf.make_addplot(pd.DataFrame(data=predictions[0], index=[amazon_data.index[j] for j in range(0,7)]).rename(columns={0: 'Open', 1: 'High', 2: 'Low', 3: 'Close', 4: 'Volume'}), type='candle', secondary_y=False),
#         mpf.make_addplot(pd.DataFrame(data=predictions[1], index=[amazon_data.index[j] for j in range(1,8)]).rename(columns={0: 'Open', 1: 'High', 2: 'Low', 3: 'Close', 4: 'Volume'}), type='candle', secondary_y=False)    
# ]
# print(apds)
# apds.append(mpf.make_addplot(open_data.head(10), type='candle', secondary_y=False))

# mpf.plot(open_data.head(10), addplot=apds, type='candle')






# !! right now its converting open_data, transforming it, inverse_transforming it, and re converting. Don't run individual transforms in succession
# open_data = scaler.inverse_transform(open_data)
# open_data = pd.DataFrame(data=open_data, index=amazon_data.index)
# open_data = open_data.rename(columns={0: 'Open', 1: 'High', 2: 'Low', 3: 'Close', 4: 'Volume'})
# print(open_data)
# mpf.plot(open_data.tail(30), type='candle', volume=True, show_nontrading=True)


# fig, ax = plt.subplots(figsize=(8,4))
# plt.plot(open_data, color="red", label="True Price of Stock")
# ax.plot(range(len(y_train)+253,len(y_train)+253+len(predictions)),predictions, color='blue', label='Predicted Testing Price')
# plt.legend()

# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
# X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
# Out:
# (280, 7, 5)
# [1.8198558e+03 1.8424785e+03 1.8139155e+03 1.8239771e+03 3.2000890e+06]
#                             Open         High          Low        Close  \
# Date
# 2020-09-16 17:00:00  3009.250000  3029.429932  2972.550049  3008.729980
# 2020-09-17 17:00:00  3031.739990  3037.800049  2905.540039  2954.909912
# 2020-09-20 17:00:00  2906.500000  2962.000000  2871.000000  2960.469971
# 2020-09-21 17:00:00  3033.840088  3133.989990  3000.199951  3128.989990
# 2020-09-22 17:00:00  3120.429932  3127.000000  2992.379883  2999.860107
# 2020-09-23 17:00:00  2977.790039  3069.300049  2965.000000  3019.790039
# 2020-09-24 17:00:00  3054.860107  3101.540039  2999.000000  3095.129883
# 2020-09-27 17:00:00  3148.850098  3175.040039  3117.169922  3174.050049
# 2020-09-28 17:00:00  3175.389893  3188.260010  3132.540039  3144.879883
# 2020-09-29 17:00:00  3141.139893  3212.879883  3133.989990  3148.729980
# 2020-10-15 17:00:00  3061025.25
# 2020-10-18 17:00:00  2901865.25
# 2020-10-19 17:00:00  2787615.25
# 2020-10-20 17:00:00  2648522.75
# 2020-10-21 17:00:00  2823062.75
# 2020-10-22 17:00:00  2787949.25
# 2020-10-25 17:00:00  2902451.50
# 2020-10-26 17:00:00  2655136.00
# 2020-10-27 17:00:00  2877953.50

# %%
from datetime import datetime
import time

def get_candlestick_data(ticker, timeframe, start, end):
    data = client.stock_candles(ticker, timeframe, start, end)
    del data['s']
    df = pd.DataFrame.from_dict(data)
    df['t'] = df['t'].apply(lambda x: datetime.fromtimestamp(x))
    df = df.rename(columns={'c': 'Close', 'h': 'High',
                            'l': 'Low', 'o': 'Open', 't': 'Date', 'v': 'Volume'})
    df.set_index('Date', inplace=True)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    return df


def stock_data_253(ticker):
    current_time = int(time.time())
    prev_time = current_time - 46656000
    df = get_candlestick_data(ticker, 'D', prev_time, current_time)
    df = df.iloc[len(df)-253:]
    return df


def get_prediction(ticker):
    data = stock_data_253(ticker)
    open_data = data.iloc[:, 0:5].to_numpy()
    scaler = MinMaxScaler(feature_range = (0, 1))
    open_data = scaler.fit_transform(data)
    x_test = [open_data[0:253]]
    x_test = np.asarray(x_test)
    model = load_model('minimize_size_weights.hdf5')
    stock_prediction = model.predict(x_test)
    stock_prediction = scaler.inverse_transform(stock_prediction.reshape(-1, stock_prediction.shape[-1])).reshape(stock_prediction.shape)
    return stock_prediction[0]


def get_prediction_df(stock_prediction):
    prediction_df = [i for i in stock_prediction]
    date_index = []
    for i in range(7):
        date_index.append(datetime.fromtimestamp((i*86400) + int(time.time()))) 
    prediction_df = pd.DataFrame(data=prediction_df, index=date_index)
    prediction_df = prediction_df.rename(columns={0: 'Open', 1: 'High', 2: 'Low', 3: 'Close', 4: 'Volume'})
    return prediction_df

# %%
kwargs = dict(type='candle',volume=True,figratio=(11,8),figscale=1.5)

target_stock_prediction = get_prediction('AAPL')
target_stock_prediction_df = get_prediction_df(target_stock_prediction)

print(target_stock_prediction)

combined_df = stock_data_253('AAPL').tail(60).append(target_stock_prediction_df)
mpf.plot(combined_df, **kwargs, style='yahoo')
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fac24861310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[1.11824135e+02 1.12456352e+02 1.06485550e+02 1.09387810e+02
#   1.32026480e+08]
#  [1.10059082e+02 1.10716820e+02 1.04838470e+02 1.07643509e+02
#   1.14732816e+08]
#  [1.11475983e+02 1.12200905e+02 1.06274117e+02 1.09049927e+02
#   1.02675760e+08]
#  [1.11389145e+02 1.12133156e+02 1.06218452e+02 1.08981606e+02
#   9.69276240e+07]
#  [1.11472496e+02 1.12217918e+02 1.06313766e+02 1.09073647e+02
#   9.46434880e+07]
#  [1.11541451e+02 1.12274246e+02 1.06382858e+02 1.09150650e+02
#   9.36011920e+07]
#  [1.11602783e+02 1.12314087e+02 1.06432159e+02 1.09221848e+02
#   9.30399120e+07]]
